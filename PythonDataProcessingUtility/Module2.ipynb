# %% [markdown]
# <h2>DataWriter</h2>
#
# DataWriter class that saves Python data into CSV, JSON, Pickle and TXT formats.
# The file extension determines which writing method is used

# %%
import csv
import json
import pickle
import os

# %% [markdown]
# __import__
# means bring a Python module/library into our program so we can use its functions.
# It is use to when our program needs to read data from or write data to CSV, JSON, PICKLE

# %%
class DataWriter:
    pass

# %% [markdown]
# __pass__ means the class is currently empty.

# %%
def save_csv(self, data, file_path):
    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(data)

# %% [markdown]
# __save_csv()__ is a method used to save data into a CSV file.
# It opens the given file in write mode and uses csv.writer() to write the data.
# writerows() is used to write multiple rows into the CSV file.

# %%
def save_json(self, data, file_path):
    with open(file_path, "w") as file:
        json.dump(data, file, indent=4)

# %% [markdown]
# __save_json()__ is a method used to save data into a JSON file.
# It uses json.dump() to write Python data into JSON format.
# The indent=4 parameter makes the JSON file properly formatted and readable.

# %%
def save_pickle(self, data, file_path):
    with open(file_path, "wb") as file:
        pickle.dump(data, file)

# %% [markdown]
# __save_pickle()__ is a method used to save Python objects into a Pickle file.
# It uses pickle.dump() to serialize and store the Python object.
# "wb" means write binary mode, which is required for Pickle files.

# %%
def save_txt(self, data, file_path):
    with open(file_path, "w") as file:
        file.write(str(data))

# %% [markdown]
# __save_txt()__ is a method used to save data into a text file.
# It uses file.write() to write the given data into the file.
# "w" means write mode, which allows the file to be created or overwritten.

# %% [markdown]
# __Complete DataWriter class__

# %%
class DataWriter:

    def save_csv(self, data, file_path):
        with open(file_path, "w", newline="") as file:
            writer = csv.writer(file)
            writer.writerows(data)

    def save_json(self, data, file_path):
        with open(file_path, "w") as file:
            json.dump(data, file, indent=4)

    def save_pickle(self, data, file_path):
        with open(file_path, "wb") as file:
            pickle.dump(data, file)

    def save_txt(self, data, file_path):
        with open(file_path, "w") as file:
            file.write(str(data))

# %%
writer = DataWriter()

# %% [markdown]
# An object is created from the DataWriter class.
# The object can use the methods defined inside the class.

# %%
data = [["Name", "Age"],["vijay", 50], ["suriya", 48]]
writer.save_csv(data, 'output.csv')
